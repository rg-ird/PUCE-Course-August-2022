# %% [markdown]
# # Introduccion de Ensamblaje del genoma mediante la secuenciación Oxford Nanopore

# %% [markdown]
# Las nuevas tecnologías de secuenciación o NGS han abierto la puerta al secuenciamiento masivo de la vida con la posibilidad de secuenciar genomas complejos y contiguos gracias a lecturas muy grandes.
# Entre estas tecnologías, la secuenciación por nanopore se distingue por un coste muy reducido, pero también un retroceso en la precisión. Se ha desarrollado una amplia gama de algoritmos para analizar datos de nanopore y hacer frente a retroceso.

# %% [markdown]
# En este curso, vamos a apprender métodos y flujo de trabajo para analizar lecturas crudas y terminar con un ensemblaje de genoma.  Veremos cómo obtener secuencias de nucleótidos a partir de señales eléctricas, profundizaremos en el paradigma de ensamblaje más utilizado para fragmentos largos, probaremos y compararemos varios ensambladores de última generación y, finalmente, evaluaremos la calidad del ensamblaje obtenido con y sin genoma de referencia.

# %% [markdown]
# Objectivos del curso:
# -Conocer las ventajas e inconvenientes de la secuenciacion Nanopore
# -Conocer el ensamblaje de novo
# -Practicar y tener experiencia en ensamblage de genoma de novo

# %% [markdown]
# Programa:
# sesion 0_
# Antes del inicio del curso, los estudiantes deben tener instalados los programas necesarios para el curso, principalmente Anaconda https://www.anaconda.com/products/distribution
# Los estudiantes deben estar familiarizados con el jupyter notebook https://jupyter-notebook.readthedocs.io/en/stable/examples/Notebook/Notebook%20Basics.html

# %% [markdown]
# # CONDA INSTALACION

# %%
Se de debe instalar algunas programas antes de iniciar el curso

# %% [markdown]
# • busco
# • canu
# • edlib
# • flye
# • miniasm
# • minimap2
# • mummer
# • nanopolish
# • quast
# • racon
# • raven-assembler
# • jupyter
# • seaborn
# • gepard
# • medaka

# %%
# !conda config --add channels bioconda
# !conda config --add channels conda-forge

# %% [markdown]
# Crear un ambiante

# %%
# !conda create -y -v --name curso
# Out:
# Removing existing environment /opt/anaconda3/envs/curso
#
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.11.0
#   latest version: 4.13.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
# initializing UnlinkLinkTransaction with
#   target_prefix: /opt/anaconda3/envs/curso
#   unlink_precs:
#
#   link_precs:
#
#
#
#
# ## Package Plan ##
#
#   environment location: /opt/anaconda3/envs/curso
#
#
#
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# #
# # To activate this environment, use
# #
# #     $ conda activate curso
# #
# # To deactivate an active environment, use
# #
# #     $ conda deactivate

# %% [markdown]
# Installar un paquete (minimap2) en el ambiante:

# %%
# !conda install -y -v -n curso minimap2
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.11.0
#   latest version: 4.13.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
# initializing UnlinkLinkTransaction with
#   target_prefix: /opt/anaconda3/envs/curso
#   unlink_precs:
#
#   link_precs:
#     conda-forge/noarch::_r-mutex-1.0.1-anacondar_1
#     conda-forge/osx-64::bzip2-1.0.8-h0d85af4_4
#     conda-forge/osx-64::c-ares-1.18.1-h0d85af4_0
#     conda-forge/osx-64::ca-certificates-2022.6.15-h033912b_0
#     conda-forge/noarch::font-ttf-dejavu-sans-mono-2.37-hab24e00_0
#     conda-forge/noarch::font-ttf-inconsolata-3.000-h77eed37_0
#     conda-forge/noarch::font-ttf-source-code-pro-2.038-h77eed37_0
#     conda-forge/noarch::font-ttf-ubuntu-0.83-hab24e00_0
#     conda-forge/osx-64::fribidi-1.0.10-hbcb3906_0
#     conda-forge/osx-64::giflib-5.2.1-hbcb3906_2
#     bioconda/osx-64::glimmerhmm-3.0.4-h470a237_2
#     bioconda/osx-64::hmmer-3.1b2-3
#     conda-forge/osx-64::jpeg-9e-hac89ed1_2
#     conda-forge/osx-64::ldid-2.1.2-h6a69015_3
#     conda-forge/osx-64::libbrotlicommon-1.0.9-h5eb16cf_7
#     conda-forge/osx-64::libdeflate-1.10-h0d85af4_0
#     conda-forge/osx-64::libev-4.33-haf1e3a3_1
#     conda-forge/osx-64::libffi-3.4.2-h0d85af4_5
#     conda-forge/noarch::libgfortran-devel_osx-64-9.3.0-h6c81a4c_23
#     conda-forge/osx-64::libiconv-1.16-haf1e3a3_0
#     conda-forge/osx-64::libogg-1.3.4-h35c211d_1
#     conda-forge/osx-64::libopus-1.3.1-hc929b4f_1
#     conda-forge/osx-64::libsodium-1.0.18-hbcb3906_1
#     conda-forge/osx-64::libunistring-0.9.10-h0d85af4_0
#     conda-forge/osx-64::libuuid-2.32.1-h35c211d_1000
#     conda-forge/osx-64::libwebp-base-1.2.3-hac89ed1_2
#     conda-forge/osx-64::llvm-openmp-14.0.4-ha654fa7_0
#     conda-forge/osx-64::lp_solve-5.5.2.5-h1de35cc_1001
#     conda-forge/osx-64::make-4.3-h22f3db7_1
#     conda-forge/osx-64::metis-5.1.0-h2e338ed_1006
#     conda-forge/osx-64::ncurses-6.3-h96cf925_1
#     conda-forge/osx-64::pandoc-2.18-h694c41f_0
#     conda-forge/osx-64::perl-5.32.1-2_h0d85af4_perl5
#     conda-forge/osx-64::pixman-0.40.0-hbcb3906_0
#     bioconda/osx-64::prodigal-2.6.3-ha5712d3_4
#     conda-forge/osx-64::pthread-stubs-0.4-hc929b4f_1001
#     conda-forge/osx-64::xorg-libxau-1.0.9-h35c211d_0
#     conda-forge/osx-64::xorg-libxdmcp-1.1.3-h35c211d_0
#     conda-forge/osx-64::xz-5.2.5-haf1e3a3_1
#     bioconda/osx-64::bamtools-2.5.1-h6151dfb_10
#     conda-forge/osx-64::expat-2.4.8-h96cf925_0
#     conda-forge/noarch::fonts-conda-forge-1-0
#     conda-forge/osx-64::gettext-0.19.8.1-hd1a6beb_1008
#     conda-forge/osx-64::gmp-6.2.1-h2e338ed_0
#     conda-forge/osx-64::graphite2-1.3.13-h2e338ed_1001
#     conda-forge/osx-64::icu-70.1-h96cf925_0
#     conda-forge/osx-64::isl-0.22.1-hb1e8313_2
#     conda-forge/osx-64::lerc-3.0-he49afe7_0
#     conda-forge/osx-64::libbrotlidec-1.0.9-h5eb16cf_7
#     conda-forge/osx-64::libbrotlienc-1.0.9-h5eb16cf_7
#     conda-forge/osx-64::libedit-3.1.20191231-h0678c8f_2
#     conda-forge/osx-64::libgfortran5-9.3.0-h6c81a4c_23
#     conda-forge/osx-64::libllvm14-14.0.6-h41df66c_0
#     conda-forge/osx-64::libvorbis-1.3.7-h046ec9c_0
#     conda-forge/osx-64::libxcb-1.13-h0d85af4_1004
#     conda-forge/osx-64::lz4-c-1.9.3-he49afe7_1
#     bioconda/osx-64::mummer-3.23-h589c0e0_12
#     conda-forge/osx-64::nspr-4.32-hcd9eead_1
#     conda-forge/osx-64::openjdk-17.0.3-hfa58983_1
#     conda-forge/osx-64::openssl-1.1.1q-hfe4f2af_0
#     conda-forge/osx-64::pbzip2-1.1.13-h9d27c22_1
#     conda-forge/osx-64::pcre-8.45-he49afe7_0
#     conda-forge/noarch::perl-app-cpanminus-1.7046-pl5321hd8ed1ab_0
#     bioconda/noarch::perl-autoloader-5.74-pl5321hdfd78af_3
#     bioconda/noarch::perl-base-2.23-pl5321hdfd78af_2
#     bioconda/noarch::perl-class-method-modifiers-2.13-pl5321hdfd78af_0
#     bioconda/noarch::perl-common-sense-3.75-pl5321hdfd78af_0
#     bioconda/osx-64::perl-compress-raw-bzip2-2.201-pl5321h9722bc1_0
#     bioconda/osx-64::perl-compress-raw-zlib-2.105-pl5321h9722bc1_0
#     conda-forge/noarch::perl-constant-1.33-pl5321hd8ed1ab_0
#     bioconda/osx-64::perl-data-dumper-2.183-pl5321ha5712d3_1
#     bioconda/osx-64::perl-dbi-1.643-pl5321ha5712d3_1
#     bioconda/noarch::perl-devel-stacktrace-2.04-pl5321hdfd78af_1
#     bioconda/noarch::perl-digest-perl-md5-1.9-pl5321hdfd78af_2
#     bioconda/noarch::perl-dynaloader-1.25-pl5321hdfd78af_2
#     conda-forge/noarch::perl-exporter-5.74-pl5321hd8ed1ab_0
#     bioconda/noarch::perl-exporter-tiny-1.002002-pl5321hdfd78af_0
#     conda-forge/noarch::perl-extutils-makemaker-7.64-pl5321hd8ed1ab_0
#     bioconda/noarch::perl-extutils-manifest-1.73-pl5321hdfd78af_0
#     conda-forge/noarch::perl-file-which-1.24-pl5321hd8ed1ab_0
#     bioconda/osx-64::perl-filesys-df-0.92-pl5321ha5712d3_5
#     bioconda/noarch::perl-getopt-long-2.52-pl5321hdfd78af_0
#     bioconda/noarch::perl-io-string-1.08-pl5321hdfd78af_4
#     bioconda/noarch::perl-io-zlib-1.11-pl5321hdfd78af_0
#     bioconda/noarch::perl-json-pp-4.11-pl5321hdfd78af_0
#     bioconda/osx-64::perl-list-moreutils-xs-0.430-pl5321ha5712d3_1
#     bioconda/noarch::perl-locale-maketext-simple-0.21-pl5321hdfd78af_3
#     bioconda/noarch::perl-math-bezier-0.01-pl5321hdfd78af_2
#     bioconda/noarch::perl-math-round-0.07-pl5321hdfd78af_2
#     bioconda/noarch::perl-math-vecstat-0.08-pl5321hdfd78af_2
#     bioconda/noarch::perl-module-load-0.34-pl5321hdfd78af_0
#     bioconda/noarch::perl-module-runtime-0.016-pl5321hdfd78af_2
#     bioconda/noarch::perl-mro-compat-0.15-pl5321hdfd78af_0
#     bioconda/osx-64::perl-package-stash-xs-0.29-pl5321h9722bc1_1
#     bioconda/noarch::perl-params-check-0.38-pl5321hdfd78af_2
#     conda-forge/noarch::perl-parent-0.238-pl5321hd8ed1ab_0
#     bioconda/noarch::perl-readonly-2.05-pl5321hdfd78af_1
#     bioconda/noarch::perl-regexp-common-2017060201-pl5321hdfd78af_1
#     bioconda/osx-64::perl-scalar-list-utils-1.62-pl5321ha5712d3_0
#     bioconda/noarch::perl-set-intspan-1.19-pl5321hdfd78af_2
#     bioconda/osx-64::perl-storable-3.15-pl5321ha5712d3_3
#     bioconda/noarch::perl-sub-exporter-progressive-0.001013-pl5321hdfd78af_1
#     bioconda/osx-64::perl-sub-identify-0.14-pl5321ha5712d3_2
#     bioconda/osx-64::perl-sub-name-0.21-pl5321ha5712d3_3
#     bioconda/noarch::perl-sub-quote-2.006006-pl5321hdfd78af_0
#     bioconda/noarch::perl-svg-2.87-pl5321hdfd78af_0
#     bioconda/noarch::perl-text-format-0.62-pl5321hdfd78af_0
#     bioconda/noarch::perl-try-tiny-0.31-pl5321hdfd78af_0
#     bioconda/osx-64::perl-version-0.9924-pl5321ha5712d3_2
#     conda-forge/noarch::perl-xsloader-0.24-pl5321hd8ed1ab_0
#     bioconda/noarch::perl-yaml-1.30-pl5321hdfd78af_0
#     conda-forge/osx-64::readline-8.1.2-h3899abd_0
#     bioconda/osx-64::spoa-4.0.7-h6151dfb_3
#     defaults/osx-64::tapi-1000.10.8-ha1b3eb9_0
#     conda-forge/osx-64::tar-1.34-hbb58dfb_0
#     conda-forge/osx-64::tbb-2021.5.0-hbb4e6a2_1
#     conda-forge/osx-64::tk-8.6.12-h5dbffcc_0
#     conda-forge/osx-64::zeromq-4.3.4-he49afe7_1
#     conda-forge/osx-64::brotli-bin-1.0.9-h5eb16cf_7
#     conda-forge/osx-64::bwidget-1.9.14-h694c41f_1
#     bioconda/osx-64::cdbtools-0.99-h6151dfb_7
#     conda-forge/noarch::fonts-conda-ecosystem-1-0
#     conda-forge/osx-64::gawk-5.1.0-h8a989fb_0
#     conda-forge/osx-64::krb5-1.19.3-hb49756b_0
#     conda-forge/osx-64::libclang13-14.0.6-default_hb5731bd_0
#     conda-forge/osx-64::libgfortran-5.0.0-9_3_0_h6c81a4c_23
#     conda-forge/osx-64::libglib-2.72.1-hfbcb929_0
#     conda-forge/osx-64::libidn2-2.3.3-hac89ed1_0
#     defaults/osx-64::libllvm12-12.0.0-h9b2ccf5_3
#     conda-forge/osx-64::libnghttp2-1.47.0-h942079c_0
#     conda-forge/osx-64::libpng-1.6.37-h5a3d3bf_3
#     conda-forge/osx-64::libssh2-1.10.0-h52ee1ee_2
#     conda-forge/osx-64::libxml2-2.9.14-h08a9926_3
#     conda-forge/osx-64::mpfr-4.1.0-h0f52abe_1
#     conda-forge/osx-64::mysql-common-8.0.30-h924029e_0
#     conda-forge/osx-64::mysql-connector-c-6.1.11-h0f02589_1007
#     conda-forge/osx-64::pcre2-10.37-ha16e1b2_0
#     conda-forge/noarch::perl-carp-1.50-pl5321hd8ed1ab_0
#     bioconda/osx-64::perl-clone-0.42-pl5321ha5712d3_2
#     bioconda/noarch::perl-devel-globaldestruction-0.14-pl5321hdfd78af_1
#     bioconda/osx-64::perl-encode-3.18-pl5321ha5712d3_0
#     conda-forge/noarch::perl-file-path-2.18-pl5321hd8ed1ab_0
#     bioconda/noarch::perl-list-moreutils-0.430-pl5321hdfd78af_0
#     bioconda/noarch::perl-module-corelist-5.20220620-pl5321hdfd78af_0
#     bioconda/osx-64::perl-params-util-1.102-pl5321hcd10b59_1
#     bioconda/noarch::perl-perl-ostype-1.010-pl5321hdfd78af_2
#     bioconda/noarch::perl-role-tiny-2.002004-pl5321hdfd78af_0
#     bioconda/noarch::perl-text-abbrev-1.02-pl5321hdfd78af_1
#     bioconda/noarch::perl-text-parsewords-3.31-pl5321hdfd78af_0
#     bioconda/noarch::perl-types-serialiser-1.01-pl5321hdfd78af_0
#     conda-forge/osx-64::perl-xml-parser-2.44_01-pl5321h06ef574_1003
#     bioconda/osx-64::raven-assembler-1.8.1-hb8176d5_0
#     conda-forge/osx-64::sqlite-3.39.2-hd9f0692_0
#     conda-forge/osx-64::tktable-2.10-h49f0cf7_3
#     conda-forge/osx-64::zstd-1.5.2-ha9df2e0_2
#     conda-forge/osx-64::boost-cpp-1.74.0-h8b082ac_8
#     conda-forge/osx-64::brotli-1.0.9-h5eb16cf_7
#     conda-forge/osx-64::freetype-2.10.4-h4cff582_1
#     conda-forge/osx-64::glib-tools-2.72.1-h2292cb8_0
#     defaults/osx-64::ld64_osx-64-530-h70f3046_23
#     conda-forge/osx-64::libclang-14.0.6-default_h55ffa42_0
#     defaults/osx-64::libclang-cpp12-12.0.0-default_hfcad0e5_2
#     conda-forge/osx-64::libcurl-7.83.1-h372c54d_0
#     conda-forge/osx-64::libopenblas-0.3.20-openmp_h4e9756f_1
#     conda-forge/osx-64::libpq-14.4-hf6bb32a_0
#     conda-forge/osx-64::libtiff-4.4.0-hfca7e8f_0
#     defaults/osx-64::llvm-tools-12.0.0-h9b2ccf5_3
#     conda-forge/osx-64::mpc-1.2.1-hbb51d92_0
#     conda-forge/osx-64::mysql-libs-8.0.30-h3cab752_0
#     conda-forge/osx-64::nss-3.78-ha8197d3_0
#     bioconda/noarch::perl-cpan-meta-requirements-2.140-pl5321hdfd78af_1
#     bioconda/noarch::perl-cpan-meta-yaml-0.018-pl5321hdfd78af_1
#     bioconda/noarch::perl-dist-checkconflicts-0.11-pl5321hdfd78af_3
#     bioconda/osx-64::perl-eval-closure-0.14-pl5321hcd10b59_6
#     conda-forge/noarch::perl-file-temp-0.2304-pl5321hd8ed1ab_0
#     bioconda/noarch::perl-font-ttf-1.06-pl5321hdfd78af_1
#     bioconda/osx-64::perl-io-compress-2.106-pl5321h9722bc1_0
#     bioconda/osx-64::perl-json-xs-2.34-pl5321hcd10b59_5
#     bioconda/noarch::perl-module-implementation-0.09-pl5321hdfd78af_3
#     bioconda/noarch::perl-module-metadata-1.000037-pl5321hdfd78af_0
#     bioconda/noarch::perl-number-format-1.75-pl5321hdfd78af_4
#     bioconda/osx-64::perl-pathtools-3.75-pl5321ha5712d3_3
#     bioconda/noarch::perl-sub-install-0.928-pl5321hdfd78af_3
#     bioconda/osx-64::perl-time-hires-1.9764-pl5321ha5712d3_2
#     conda-forge/osx-64::python-3.7.12-haf480d7_100_cpython
#     bioconda/osx-64::ucsc-fatotwobit-377-h516baf0_3
#     bioconda/osx-64::ucsc-twobitinfo-377-h516baf0_1
#     conda-forge/osx-64::wget-1.20.3-h52ee1ee_1
#     conda-forge/noarch::appnope-0.1.3-pyhd8ed1ab_0
#     conda-forge/noarch::attrs-22.1.0-pyh71513ae_1
#     conda-forge/noarch::backcall-0.2.0-pyh9f0ad1d_0
#     conda-forge/noarch::backports-1.0-py_2
#     defaults/osx-64::cctools_osx-64-949.0.1-hc7db93f_23
#     defaults/osx-64::clang-12-12.0.0-default_hfcad0e5_2
#     conda-forge/osx-64::curl-7.83.1-h372c54d_0
#     conda-forge/noarch::cycler-0.11.0-pyhd8ed1ab_0
#     conda-forge/noarch::decorator-5.1.1-pyhd8ed1ab_0
#     conda-forge/noarch::defusedxml-0.7.1-pyhd8ed1ab_0
#     bioconda/noarch::dendropy-4.5.2-pyh3252c3a_0
#     bioconda/osx-64::diamond-2.0.15-h9d1909e_0
#     bioconda/osx-64::entrez-direct-16.2-h193322a_1
#     conda-forge/noarch::entrypoints-0.4-pyhd8ed1ab_0
#     conda-forge/noarch::flit-core-3.7.1-pyhd8ed1ab_0
#     conda-forge/osx-64::fontconfig-2.14.0-h676cef8_0
#     conda-forge/osx-64::gfortran_impl_osx-64-9.3.0-h9cc0e5e_23
#     conda-forge/osx-64::glib-2.72.1-h2292cb8_0
#     conda-forge/osx-64::hdf5-1.10.6-nompi_hc5d9132_1114
#     bioconda/osx-64::htslib-1.15.1-hc057d7f_0
#     conda-forge/noarch::ipython_genutils-0.2.0-py_1
#     conda-forge/noarch::jupyterlab_widgets-1.1.1-pyhd8ed1ab_0
#     conda-forge/osx-64::lcms2-2.12-h577c468_0
#     conda-forge/osx-64::libblas-3.9.0-15_osx64_openblas
#     conda-forge/osx-64::libwebp-1.2.3-hf64df63_1
#     bioconda/osx-64::metaeuk-6.a5d39d9-pl5321hdb1ff06_0
#     conda-forge/noarch::munkres-1.1.4-pyh9f0ad1d_0
#     conda-forge/noarch::nest-asyncio-1.5.5-pyhd8ed1ab_0
#     conda-forge/osx-64::openjpeg-2.4.0-h6e7aa92_1
#     conda-forge/noarch::pandocfilters-1.5.0-pyhd8ed1ab_0
#     conda-forge/noarch::parso-0.8.3-pyhd8ed1ab_0
#     bioconda/noarch::perl-apache-test-1.43-pl5321hdfd78af_0
#     bioconda/noarch::perl-archive-tar-2.40-pl5321hdfd78af_0
#     bioconda/noarch::perl-config-general-2.65-pl5321hdfd78af_0
#     bioconda/noarch::perl-cpan-meta-2.150010-pl5321hdfd78af_1
#     bioconda/noarch::perl-data-optlist-0.112-pl5321hdfd78af_0
#     bioconda/noarch::perl-json-4.09-pl5321hdfd78af_0
#     bioconda/noarch::perl-module-load-conditional-0.68-pl5321hdfd78af_3
#     bioconda/noarch::perl-module-runtime-conflicts-0.003-pl5321hdfd78af_1
#     bioconda/osx-64::perl-params-validate-1.30-pl5321ha5712d3_1
#     bioconda/noarch::perl-statistics-basic-1.6611-pl5321hdfd78af_3
#     conda-forge/noarch::pickleshare-0.7.5-py_1003
#     conda-forge/noarch::pkgutil-resolve-name-1.3.10-pyhd8ed1ab_0
#     conda-forge/noarch::ply-3.11-py_1
#     conda-forge/noarch::prometheus_client-0.14.1-pyhd8ed1ab_0
#     conda-forge/noarch::ptyprocess-0.7.0-pyhd3deb0d_0
#     conda-forge/noarch::pycparser-2.21-pyhd8ed1ab_0
#     conda-forge/noarch::pyparsing-3.0.9-pyhd8ed1ab_0
#     conda-forge/noarch::python-fastjsonschema-2.16.1-pyhd8ed1ab_0
#     conda-forge/osx-64::python_abi-3.7-2_cp37m
#     conda-forge/noarch::pytz-2022.1-pyhd8ed1ab_0
#     bioconda/osx-64::racon-1.5.0-h895c61e_0
#     conda-forge/noarch::send2trash-1.8.0-pyhd8ed1ab_0
#     conda-forge/noarch::six-1.16.0-pyh6c4a22f_0
#     conda-forge/noarch::soupsieve-2.3.2.post1-pyhd8ed1ab_0
#     conda-forge/noarch::toml-0.10.2-pyhd8ed1ab_0
#     conda-forge/noarch::traitlets-5.3.0-pyhd8ed1ab_0
#     conda-forge/noarch::typing_extensions-4.3.0-pyha770c72_0
#     conda-forge/noarch::webencodings-0.5.1-py_1
#     conda-forge/noarch::wheel-0.37.1-pyhd8ed1ab_0
#     conda-forge/noarch::zipp-3.8.1-pyhd8ed1ab_0
#     conda-forge/noarch::beautifulsoup4-4.11.1-pyha770c72_0
#     bioconda/osx-64::blast-2.12.0-h0370960_3
#     conda-forge/osx-64::cairo-1.16.0-h1680b09_1011
#     conda-forge/osx-64::certifi-2022.6.15-py37hf985489_0
#     conda-forge/osx-64::cffi-1.15.1-py37haabf53d_0
#     defaults/osx-64::clang-12.0.0-hecd8cb5_2
#     conda-forge/osx-64::debugpy-1.6.0-py37h0582d14_0
#     conda-forge/osx-64::edlib-1.3.9-py37h18621fa_2
#     conda-forge/osx-64::gstreamer-1.20.3-hdc08c3f_0
#     conda-forge/osx-64::importlib-metadata-4.11.4-py37hf985489_0
#     conda-forge/noarch::importlib_resources-5.9.0-pyhd8ed1ab_0
#     conda-forge/osx-64::jedi-0.18.1-py37hf985489_1
#     conda-forge/osx-64::jupyter_core-4.11.1-py37hf985489_0
#     conda-forge/osx-64::libcblas-3.9.0-15_osx64_openblas
#     conda-forge/osx-64::libgd-2.3.3-h1e214de_3
#     conda-forge/osx-64::liblapack-3.9.0-15_osx64_openblas
#     conda-forge/osx-64::markupsafe-2.1.1-py37h69ee0a8_1
#     conda-forge/noarch::matplotlib-inline-0.1.3-pyhd8ed1ab_0
#     conda-forge/osx-64::mistune-0.8.4-py37h271585c_1005
#     bioconda/osx-64::ont_vbz_hdf_plugin-1.0.1-hbef3b0f_2
#     conda-forge/noarch::packaging-21.3-pyhd8ed1ab_0
#     bioconda/noarch::perl-ipc-cmd-1.04-pl5321hdfd78af_0
#     bioconda/osx-64::perl-package-stash-0.40-pl5321h9722bc1_1
#     bioconda/noarch::perl-sub-exporter-0.988-pl5321hdfd78af_0
#     conda-forge/noarch::pexpect-4.8.0-pyh9f0ad1d_2
#     conda-forge/osx-64::pillow-9.2.0-py37h1eb1bbc_0
#     conda-forge/osx-64::psutil-5.9.1-py37h994c40b_0
#     conda-forge/osx-64::pyrsistent-0.18.1-py37h69ee0a8_1
#     conda-forge/noarch::python-dateutil-2.8.2-pyhd8ed1ab_0
#     conda-forge/osx-64::pyzmq-23.2.0-py37h573e605_0
#     bioconda/osx-64::samtools-1.15.1-h9f30945_0
#     bioconda/osx-64::sepp-4.5.1-py37hd9614f4_1
#     conda-forge/osx-64::setuptools-59.8.0-py37hf985489_1
#     conda-forge/osx-64::simplejson-3.17.6-py37h69ee0a8_1
#     conda-forge/noarch::tinycss2-1.1.1-pyhd8ed1ab_0
#     conda-forge/osx-64::tornado-6.2-py37h994c40b_0
#     conda-forge/noarch::typing-extensions-4.3.0-hd8ed1ab_0
#     conda-forge/osx-64::unicodedata2-14.0.0-py37h69ee0a8_1
#     conda-forge/osx-64::argon2-cffi-bindings-21.2.0-py37h69ee0a8_2
#     conda-forge/noarch::backports.functools_lru_cache-1.6.4-pyhd8ed1ab_0
#     bioconda/osx-64::bbmap-38.97-h3fae6ef_0
#     conda-forge/noarch::bleach-5.0.1-pyhd8ed1ab_0
#     defaults/osx-64::clangxx-12.0.0-default_hfcad0e5_2
#     bioconda/osx-64::flye-2.9-py37h18d0eb1_1
#     conda-forge/osx-64::fonttools-4.34.4-py37h994c40b_0
#     conda-forge/osx-64::gsl-2.7-h93259b0_0
#     conda-forge/osx-64::gst-plugins-base-1.20.3-hda0ba4b_0
#     conda-forge/osx-64::harfbuzz-5.1.0-h00bb2c2_0
#     conda-forge/noarch::jinja2-3.1.2-pyhd8ed1ab_1
#     conda-forge/noarch::joblib-1.1.0-pyhd8ed1ab_0
#     conda-forge/noarch::jsonschema-4.9.1-pyhd8ed1ab_0
#     conda-forge/noarch::jupyter_client-7.3.4-pyhd8ed1ab_0
#     conda-forge/osx-64::kiwisolver-1.4.4-py37h229a17a_0
#     conda-forge/osx-64::numpy-1.21.6-py37h345d48f_0
#     bioconda/noarch::perl-class-load-0.25-pl5321hdfd78af_1
#     bioconda/noarch::perl-devel-overloadinfo-0.007-pl5321hdfd78af_0
#     bioconda/noarch::perl-extutils-cbuilder-0.280230-pl5321hdfd78af_2
#     bioconda/osx-64::perl-gd-2.76-pl5321hb8176d5_1
#     bioconda/noarch::perl-package-deprecationmanager-0.17-pl5321hdfd78af_1
#     conda-forge/noarch::pip-22.2.1-pyhd8ed1ab_0
#     conda-forge/noarch::pygments-2.12.0-pyhd8ed1ab_0
#     conda-forge/noarch::qtpy-2.1.0-pyhd8ed1ab_0
#     conda-forge/osx-64::sip-6.6.2-py37hc568d09_0
#     conda-forge/osx-64::suitesparse-5.10.1-h7aff33d_1
#     conda-forge/osx-64::terminado-0.15.0-py37hf985489_0
#     conda-forge/noarch::argon2-cffi-21.3.0-pyhd8ed1ab_0
#     conda-forge/osx-64::biopython-1.79-py37h69ee0a8_2
#     bioconda/noarch::circos-0.69.8-hdfd78af_1
#     defaults/noarch::compiler-rt_osx-64-12.0.0-hfb26b64_2
#     conda-forge/noarch::jupyterlab_pygments-0.2.2-pyhd8ed1ab_0
#     conda-forge/osx-64::matplotlib-base-3.5.2-py37h80cb303_1
#     conda-forge/noarch::nbformat-5.4.0-pyhd8ed1ab_0
#     conda-forge/osx-64::pandas-1.3.4-py37h5b83a90_1
#     conda-forge/osx-64::pango-1.50.8-he4563bb_1
#     bioconda/osx-64::perl-class-load-xs-0.10-pl5321hcd10b59_6
#     bioconda/noarch::perl-extutils-parsexs-3.44-pl5321hdfd78af_0
#     conda-forge/osx-64::pyqt5-sip-12.11.0-py37h453a0d4_0
#     conda-forge/osx-64::qt-main-5.15.4-h938c29d_2
#     conda-forge/noarch::wcwidth-0.2.5-pyh9f0ad1d_2
#     defaults/osx-64::compiler-rt-12.0.0-hd87ff74_2
#     conda-forge/osx-64::gnuplot-5.4.4-h8cdca01_0
#     bioconda/osx-64::nanopolish-0.14.0-h7d00a20_0
#     conda-forge/noarch::nbclient-0.6.6-pyhd8ed1ab_0
#     bioconda/noarch::perl-module-build-0.4231-pl5321hdfd78af_0
#     bioconda/osx-64::perl-moose-2.2201-pl5321ha5712d3_2
#     conda-forge/noarch::prompt-toolkit-3.0.30-pyha770c72_0
#     conda-forge/osx-64::pyqt-5.15.7-py37h6d02c96_0
#     bioconda/osx-64::quast-5.2.0-py37pl5321h02f24ee_1
#     bioconda/osx-64::canu-2.2-hbe63672_0
#     defaults/osx-64::clang_osx-64-12.0.0-h7ad7729_2
#     conda-forge/osx-64::ipython-7.33.0-py37hf985489_0
#     conda-forge/noarch::nbconvert-core-6.5.0-pyhd8ed1ab_0
#     bioconda/noarch::perl-moo-2.005004-pl5321hdfd78af_0
#     conda-forge/noarch::prompt_toolkit-3.0.30-hd8ed1ab_0
#     defaults/osx-64::clangxx_osx-64-12.0.0-he0c6f94_2
#     conda-forge/osx-64::gfortran_osx-64-9.3.0-h18f7dce_15
#     conda-forge/noarch::ipykernel-6.15.1-pyh736e0ef_0
#     conda-forge/noarch::nbconvert-pandoc-6.5.0-pyhd8ed1ab_0
#     bioconda/noarch::perl-parallel-forkmanager-2.02-pl5321hdfd78af_1
#     bioconda/osx-64::augustus-3.4.0-pl5321he8e39e9_6
#     conda-forge/noarch::jupyter_console-6.4.4-pyhd8ed1ab_0
#     conda-forge/noarch::nbconvert-6.5.0-pyhd8ed1ab_0
#     conda-forge/noarch::qtconsole-base-5.3.1-pyha770c72_0
#     conda-forge/osx-64::r-base-4.1.3-h234e2ac_1
#     conda-forge/noarch::notebook-6.4.12-pyha770c72_0
#     conda-forge/noarch::qtconsole-5.3.1-pyhd8ed1ab_0
#     conda-forge/osx-64::r-backports-1.4.1-r41h28b5c78_0
#     conda-forge/osx-64::r-brio-1.1.3-r41h28b5c78_0
#     conda-forge/osx-64::r-colorspace-2.0_3-r41h0f1d5c4_0
#     conda-forge/noarch::r-crayon-1.5.1-r41hc72bb7e_0
#     conda-forge/osx-64::r-digest-0.6.29-r41h9951f98_0
#     conda-forge/noarch::r-evaluate-0.15-r41hc72bb7e_0
#     conda-forge/osx-64::r-fansi-1.0.3-r41h0f1d5c4_0
#     conda-forge/osx-64::r-farver-2.1.1-r41h8619c4b_0
#     conda-forge/osx-64::r-fs-1.5.2-r41hc4bb905_1
#     conda-forge/osx-64::r-glue-1.6.2-r41h0f1d5c4_0
#     conda-forge/noarch::r-gtable-0.3.0-r41hc72bb7e_3
#     conda-forge/osx-64::r-jsonlite-1.8.0-r41h0f1d5c4_0
#     conda-forge/noarch::r-labeling-0.4.2-r41hc72bb7e_1
#     conda-forge/osx-64::r-lattice-0.20_45-r41h28b5c78_0
#     conda-forge/osx-64::r-magrittr-2.0.3-r41h0f1d5c4_0
#     conda-forge/osx-64::r-mass-7.3_58-r41h67d6963_0
#     conda-forge/noarch::r-pkgconfig-2.0.3-r41hc72bb7e_1
#     conda-forge/noarch::r-praise-1.0.0-r41hc72bb7e_1005
#     conda-forge/osx-64::r-ps-1.7.1-r41h67d6963_0
#     conda-forge/noarch::r-r6-2.5.1-r41hc72bb7e_0
#     conda-forge/noarch::r-rcolorbrewer-1.1_3-r41h785f33e_0
#     conda-forge/osx-64::r-rcpp-1.0.9-r41h8619c4b_0
#     conda-forge/osx-64::r-rlang-1.0.4-r41h8619c4b_0
#     conda-forge/osx-64::r-utf8-1.2.2-r41h28b5c78_0
#     conda-forge/noarch::r-viridislite-0.4.0-r41hc72bb7e_0
#     conda-forge/noarch::r-withr-2.5.0-r41hc72bb7e_0
#     conda-forge/osx-64::r-cli-3.3.0-r41h8619c4b_0
#     conda-forge/osx-64::r-diffobj-0.3.5-r41h28b5c78_0
#     conda-forge/osx-64::r-ellipsis-0.3.2-r41h28b5c78_0
#     conda-forge/noarch::r-lifecycle-1.0.1-r41hc72bb7e_0
#     conda-forge/osx-64::r-matrix-1.4_1-r41ha2825d1_0
#     conda-forge/noarch::r-munsell-0.5.0-r41hc72bb7e_1004
#     conda-forge/osx-64::r-nlme-3.1_158-r41he3b5f32_0
#     conda-forge/osx-64::r-processx-3.7.0-r41h67d6963_0
#     conda-forge/noarch::r-rprojroot-2.0.3-r41hc72bb7e_0
#     conda-forge/noarch::widgetsnbextension-3.6.1-pyha770c72_0
#     conda-forge/noarch::ipywidgets-7.7.1-pyhd8ed1ab_0
#     conda-forge/noarch::r-callr-3.7.1-r41hc72bb7e_0
#     conda-forge/noarch::r-desc-1.4.1-r41hc72bb7e_0
#     conda-forge/osx-64::r-mgcv-1.8_40-r41h60b693f_0
#     conda-forge/noarch::r-scales-1.2.0-r41hc72bb7e_0
#     conda-forge/osx-64::r-vctrs-0.4.1-r41hc4bb905_0
#     conda-forge/osx-64::jupyter-1.0.0-py37hf985489_7
#     conda-forge/noarch::r-pillar-1.8.0-r41hc72bb7e_0
#     conda-forge/noarch::r-pkgload-1.3.0-r41hc72bb7e_0
#     conda-forge/osx-64::r-tibble-3.1.8-r41h67d6963_0
#     conda-forge/noarch::r-rematch2-2.1.2-r41hc72bb7e_1
#     conda-forge/noarch::r-waldo-0.4.0-r41hc72bb7e_0
#     conda-forge/osx-64::r-testthat-3.1.4-r41h8619c4b_0
#     conda-forge/osx-64::r-isoband-0.2.5-r41h9951f98_0
#     conda-forge/noarch::r-ggplot2-3.3.6-r41hc72bb7e_0
#     bioconda/noarch::busco-5.4.2-pyhdfd78af_0
# ## Package Plan ##
#
#   environment location: /opt/anaconda3/envs/curso
#
#   added / updated specs:
#     - busco
#     - canu
#     - edlib
#     - flye
#     - jupyter
#     - miniasm
#     - minimap2
#     - mummer
#     - nanopolish
#     - quast
#     - racon
#     - raven-assembler
#     - spoa
#
#
# The following NEW packages will be INSTALLED:
#
#   _r-mutex           conda-forge/noarch::_r-mutex-1.0.1-anacondar_1
#   appnope            conda-forge/noarch::appnope-0.1.3-pyhd8ed1ab_0
#   argon2-cffi        conda-forge/noarch::argon2-cffi-21.3.0-pyhd8ed1ab_0
#   argon2-cffi-bindi~ conda-forge/osx-64::argon2-cffi-bindings-21.2.0-py37h69ee0a8_2
#   attrs              conda-forge/noarch::attrs-22.1.0-pyh71513ae_1
#   augustus           bioconda/osx-64::augustus-3.4.0-pl5321he8e39e9_6
#   backcall           conda-forge/noarch::backcall-0.2.0-pyh9f0ad1d_0
#   backports          conda-forge/noarch::backports-1.0-py_2
#   backports.functoo~ conda-forge/noarch::backports.functools_lru_cache-1.6.4-pyhd8ed1ab_0
#   bamtools           bioconda/osx-64::bamtools-2.5.1-h6151dfb_10
#   bbmap              bioconda/osx-64::bbmap-38.97-h3fae6ef_0
#   beautifulsoup4     conda-forge/noarch::beautifulsoup4-4.11.1-pyha770c72_0
#   biopython          conda-forge/osx-64::biopython-1.79-py37h69ee0a8_2
#   blast              bioconda/osx-64::blast-2.12.0-h0370960_3
#   bleach             conda-forge/noarch::bleach-5.0.1-pyhd8ed1ab_0
#   boost-cpp          conda-forge/osx-64::boost-cpp-1.74.0-h8b082ac_8
#   brotli             conda-forge/osx-64::brotli-1.0.9-h5eb16cf_7
#   brotli-bin         conda-forge/osx-64::brotli-bin-1.0.9-h5eb16cf_7
#   busco              bioconda/noarch::busco-5.4.2-pyhdfd78af_0
#   bwidget            conda-forge/osx-64::bwidget-1.9.14-h694c41f_1
#   bzip2              conda-forge/osx-64::bzip2-1.0.8-h0d85af4_4
#   c-ares             conda-forge/osx-64::c-ares-1.18.1-h0d85af4_0
#   ca-certificates    conda-forge/osx-64::ca-certificates-2022.6.15-h033912b_0
#   cairo              conda-forge/osx-64::cairo-1.16.0-h1680b09_1011
#   canu               bioconda/osx-64::canu-2.2-hbe63672_0
#   cctools_osx-64     pkgs/main/osx-64::cctools_osx-64-949.0.1-hc7db93f_23
#   cdbtools           bioconda/osx-64::cdbtools-0.99-h6151dfb_7
#   certifi            conda-forge/osx-64::certifi-2022.6.15-py37hf985489_0
#   cffi               conda-forge/osx-64::cffi-1.15.1-py37haabf53d_0
#   circos             bioconda/noarch::circos-0.69.8-hdfd78af_1
#   clang              pkgs/main/osx-64::clang-12.0.0-hecd8cb5_2
#   clang-12           pkgs/main/osx-64::clang-12-12.0.0-default_hfcad0e5_2
#   clang_osx-64       pkgs/main/osx-64::clang_osx-64-12.0.0-h7ad7729_2
#   clangxx            pkgs/main/osx-64::clangxx-12.0.0-default_hfcad0e5_2
#   clangxx_osx-64     pkgs/main/osx-64::clangxx_osx-64-12.0.0-he0c6f94_2
#   compiler-rt        pkgs/main/osx-64::compiler-rt-12.0.0-hd87ff74_2
#   compiler-rt_osx-64 pkgs/main/noarch::compiler-rt_osx-64-12.0.0-hfb26b64_2
#   curl               conda-forge/osx-64::curl-7.83.1-h372c54d_0
#   cycler             conda-forge/noarch::cycler-0.11.0-pyhd8ed1ab_0
#   debugpy            conda-forge/osx-64::debugpy-1.6.0-py37h0582d14_0
#   decorator          conda-forge/noarch::decorator-5.1.1-pyhd8ed1ab_0
#   defusedxml         conda-forge/noarch::defusedxml-0.7.1-pyhd8ed1ab_0
#   dendropy           bioconda/noarch::dendropy-4.5.2-pyh3252c3a_0
#   diamond            bioconda/osx-64::diamond-2.0.15-h9d1909e_0
#   edlib              conda-forge/osx-64::edlib-1.3.9-py37h18621fa_2
#   entrez-direct      bioconda/osx-64::entrez-direct-16.2-h193322a_1
#   entrypoints        conda-forge/noarch::entrypoints-0.4-pyhd8ed1ab_0
#   expat              conda-forge/osx-64::expat-2.4.8-h96cf925_0
#   flit-core          conda-forge/noarch::flit-core-3.7.1-pyhd8ed1ab_0
#   flye               bioconda/osx-64::flye-2.9-py37h18d0eb1_1
#   font-ttf-dejavu-s~ conda-forge/noarch::font-ttf-dejavu-sans-mono-2.37-hab24e00_0
#   font-ttf-inconsol~ conda-forge/noarch::font-ttf-inconsolata-3.000-h77eed37_0
#   font-ttf-source-c~ conda-forge/noarch::font-ttf-source-code-pro-2.038-h77eed37_0
#   font-ttf-ubuntu    conda-forge/noarch::font-ttf-ubuntu-0.83-hab24e00_0
#   fontconfig         conda-forge/osx-64::fontconfig-2.14.0-h676cef8_0
#   fonts-conda-ecosy~ conda-forge/noarch::fonts-conda-ecosystem-1-0
#   fonts-conda-forge  conda-forge/noarch::fonts-conda-forge-1-0
#   fonttools          conda-forge/osx-64::fonttools-4.34.4-py37h994c40b_0
#   freetype           conda-forge/osx-64::freetype-2.10.4-h4cff582_1
#   fribidi            conda-forge/osx-64::fribidi-1.0.10-hbcb3906_0
#   gawk               conda-forge/osx-64::gawk-5.1.0-h8a989fb_0
#   gettext            conda-forge/osx-64::gettext-0.19.8.1-hd1a6beb_1008
#   gfortran_impl_osx~ conda-forge/osx-64::gfortran_impl_osx-64-9.3.0-h9cc0e5e_23
#   gfortran_osx-64    conda-forge/osx-64::gfortran_osx-64-9.3.0-h18f7dce_15
#   giflib             conda-forge/osx-64::giflib-5.2.1-hbcb3906_2
#   glib               conda-forge/osx-64::glib-2.72.1-h2292cb8_0
#   glib-tools         conda-forge/osx-64::glib-tools-2.72.1-h2292cb8_0
#   glimmerhmm         bioconda/osx-64::glimmerhmm-3.0.4-h470a237_2
#   gmp                conda-forge/osx-64::gmp-6.2.1-h2e338ed_0
#   gnuplot            conda-forge/osx-64::gnuplot-5.4.4-h8cdca01_0
#   graphite2          conda-forge/osx-64::graphite2-1.3.13-h2e338ed_1001
#   gsl                conda-forge/osx-64::gsl-2.7-h93259b0_0
#   gst-plugins-base   conda-forge/osx-64::gst-plugins-base-1.20.3-hda0ba4b_0
#   gstreamer          conda-forge/osx-64::gstreamer-1.20.3-hdc08c3f_0
#   harfbuzz           conda-forge/osx-64::harfbuzz-5.1.0-h00bb2c2_0
#   hdf5               conda-forge/osx-64::hdf5-1.10.6-nompi_hc5d9132_1114
#   hmmer              bioconda/osx-64::hmmer-3.1b2-3
#   htslib             bioconda/osx-64::htslib-1.15.1-hc057d7f_0
#   icu                conda-forge/osx-64::icu-70.1-h96cf925_0
#   importlib-metadata conda-forge/osx-64::importlib-metadata-4.11.4-py37hf985489_0
#   importlib_resourc~ conda-forge/noarch::importlib_resources-5.9.0-pyhd8ed1ab_0
#   ipykernel          conda-forge/noarch::ipykernel-6.15.1-pyh736e0ef_0
#   ipython            conda-forge/osx-64::ipython-7.33.0-py37hf985489_0
#   ipython_genutils   conda-forge/noarch::ipython_genutils-0.2.0-py_1
#   ipywidgets         conda-forge/noarch::ipywidgets-7.7.1-pyhd8ed1ab_0
#   isl                conda-forge/osx-64::isl-0.22.1-hb1e8313_2
#   jedi               conda-forge/osx-64::jedi-0.18.1-py37hf985489_1
#   jinja2             conda-forge/noarch::jinja2-3.1.2-pyhd8ed1ab_1
#   joblib             conda-forge/noarch::joblib-1.1.0-pyhd8ed1ab_0
#   jpeg               conda-forge/osx-64::jpeg-9e-hac89ed1_2
#   jsonschema         conda-forge/noarch::jsonschema-4.9.1-pyhd8ed1ab_0
#   jupyter            conda-forge/osx-64::jupyter-1.0.0-py37hf985489_7
#   jupyter_client     conda-forge/noarch::jupyter_client-7.3.4-pyhd8ed1ab_0
#   jupyter_console    conda-forge/noarch::jupyter_console-6.4.4-pyhd8ed1ab_0
#   jupyter_core       conda-forge/osx-64::jupyter_core-4.11.1-py37hf985489_0
#   jupyterlab_pygmen~ conda-forge/noarch::jupyterlab_pygments-0.2.2-pyhd8ed1ab_0
#   jupyterlab_widgets conda-forge/noarch::jupyterlab_widgets-1.1.1-pyhd8ed1ab_0
#   kiwisolver         conda-forge/osx-64::kiwisolver-1.4.4-py37h229a17a_0
#   krb5               conda-forge/osx-64::krb5-1.19.3-hb49756b_0
#   lcms2              conda-forge/osx-64::lcms2-2.12-h577c468_0
#   ld64_osx-64        pkgs/main/osx-64::ld64_osx-64-530-h70f3046_23
#   ldid               conda-forge/osx-64::ldid-2.1.2-h6a69015_3
#   lerc               conda-forge/osx-64::lerc-3.0-he49afe7_0
#   libblas            conda-forge/osx-64::libblas-3.9.0-15_osx64_openblas
#   libbrotlicommon    conda-forge/osx-64::libbrotlicommon-1.0.9-h5eb16cf_7
#   libbrotlidec       conda-forge/osx-64::libbrotlidec-1.0.9-h5eb16cf_7
#   libbrotlienc       conda-forge/osx-64::libbrotlienc-1.0.9-h5eb16cf_7
#   libcblas           conda-forge/osx-64::libcblas-3.9.0-15_osx64_openblas
#   libclang           conda-forge/osx-64::libclang-14.0.6-default_h55ffa42_0
#   libclang-cpp12     pkgs/main/osx-64::libclang-cpp12-12.0.0-default_hfcad0e5_2
#   libclang13         conda-forge/osx-64::libclang13-14.0.6-default_hb5731bd_0
#   libcurl            conda-forge/osx-64::libcurl-7.83.1-h372c54d_0
#   libdeflate         conda-forge/osx-64::libdeflate-1.10-h0d85af4_0
#   libedit            conda-forge/osx-64::libedit-3.1.20191231-h0678c8f_2
#   libev              conda-forge/osx-64::libev-4.33-haf1e3a3_1
#   libffi             conda-forge/osx-64::libffi-3.4.2-h0d85af4_5
#   libgd              conda-forge/osx-64::libgd-2.3.3-h1e214de_3
#   libgfortran        conda-forge/osx-64::libgfortran-5.0.0-9_3_0_h6c81a4c_23
#   libgfortran-devel~ conda-forge/noarch::libgfortran-devel_osx-64-9.3.0-h6c81a4c_23
#   libgfortran5       conda-forge/osx-64::libgfortran5-9.3.0-h6c81a4c_23
#   libglib            conda-forge/osx-64::libglib-2.72.1-hfbcb929_0
#   libiconv           conda-forge/osx-64::libiconv-1.16-haf1e3a3_0
#   libidn2            conda-forge/osx-64::libidn2-2.3.3-hac89ed1_0
#   liblapack          conda-forge/osx-64::liblapack-3.9.0-15_osx64_openblas
#   libllvm12          pkgs/main/osx-64::libllvm12-12.0.0-h9b2ccf5_3
#   libllvm14          conda-forge/osx-64::libllvm14-14.0.6-h41df66c_0
#   libnghttp2         conda-forge/osx-64::libnghttp2-1.47.0-h942079c_0
#   libogg             conda-forge/osx-64::libogg-1.3.4-h35c211d_1
#   libopenblas        conda-forge/osx-64::libopenblas-0.3.20-openmp_h4e9756f_1
#   libopus            conda-forge/osx-64::libopus-1.3.1-hc929b4f_1
#   libpng             conda-forge/osx-64::libpng-1.6.37-h5a3d3bf_3
#   libpq              conda-forge/osx-64::libpq-14.4-hf6bb32a_0
#   libsodium          conda-forge/osx-64::libsodium-1.0.18-hbcb3906_1
#   libssh2            conda-forge/osx-64::libssh2-1.10.0-h52ee1ee_2
#   libtiff            conda-forge/osx-64::libtiff-4.4.0-hfca7e8f_0
#   libunistring       conda-forge/osx-64::libunistring-0.9.10-h0d85af4_0
#   libuuid            conda-forge/osx-64::libuuid-2.32.1-h35c211d_1000
#   libvorbis          conda-forge/osx-64::libvorbis-1.3.7-h046ec9c_0
#   libwebp            conda-forge/osx-64::libwebp-1.2.3-hf64df63_1
#   libwebp-base       conda-forge/osx-64::libwebp-base-1.2.3-hac89ed1_2
#   libxcb             conda-forge/osx-64::libxcb-1.13-h0d85af4_1004
#   libxml2            conda-forge/osx-64::libxml2-2.9.14-h08a9926_3
#   llvm-openmp        conda-forge/osx-64::llvm-openmp-14.0.4-ha654fa7_0
#   llvm-tools         pkgs/main/osx-64::llvm-tools-12.0.0-h9b2ccf5_3
#   lp_solve           conda-forge/osx-64::lp_solve-5.5.2.5-h1de35cc_1001
#   lz4-c              conda-forge/osx-64::lz4-c-1.9.3-he49afe7_1
#   make               conda-forge/osx-64::make-4.3-h22f3db7_1
#   markupsafe         conda-forge/osx-64::markupsafe-2.1.1-py37h69ee0a8_1
#   matplotlib-base    conda-forge/osx-64::matplotlib-base-3.5.2-py37h80cb303_1
#   matplotlib-inline  conda-forge/noarch::matplotlib-inline-0.1.3-pyhd8ed1ab_0
#   metaeuk            bioconda/osx-64::metaeuk-6.a5d39d9-pl5321hdb1ff06_0
#   metis              conda-forge/osx-64::metis-5.1.0-h2e338ed_1006
#   mistune            conda-forge/osx-64::mistune-0.8.4-py37h271585c_1005
#   mpc                conda-forge/osx-64::mpc-1.2.1-hbb51d92_0
#   mpfr               conda-forge/osx-64::mpfr-4.1.0-h0f52abe_1
#   mummer             bioconda/osx-64::mummer-3.23-h589c0e0_12
#   munkres            conda-forge/noarch::munkres-1.1.4-pyh9f0ad1d_0
#   mysql-common       conda-forge/osx-64::mysql-common-8.0.30-h924029e_0
#   mysql-connector-c  conda-forge/osx-64::mysql-connector-c-6.1.11-h0f02589_1007
#   mysql-libs         conda-forge/osx-64::mysql-libs-8.0.30-h3cab752_0
#   nanopolish         bioconda/osx-64::nanopolish-0.14.0-h7d00a20_0
#   nbclient           conda-forge/noarch::nbclient-0.6.6-pyhd8ed1ab_0
#   nbconvert          conda-forge/noarch::nbconvert-6.5.0-pyhd8ed1ab_0
#   nbconvert-core     conda-forge/noarch::nbconvert-core-6.5.0-pyhd8ed1ab_0
#   nbconvert-pandoc   conda-forge/noarch::nbconvert-pandoc-6.5.0-pyhd8ed1ab_0
#   nbformat           conda-forge/noarch::nbformat-5.4.0-pyhd8ed1ab_0
#   ncurses            conda-forge/osx-64::ncurses-6.3-h96cf925_1
#   nest-asyncio       conda-forge/noarch::nest-asyncio-1.5.5-pyhd8ed1ab_0
#   notebook           conda-forge/noarch::notebook-6.4.12-pyha770c72_0
#   nspr               conda-forge/osx-64::nspr-4.32-hcd9eead_1
#   nss                conda-forge/osx-64::nss-3.78-ha8197d3_0
#   numpy              conda-forge/osx-64::numpy-1.21.6-py37h345d48f_0
#   ont_vbz_hdf_plugin bioconda/osx-64::ont_vbz_hdf_plugin-1.0.1-hbef3b0f_2
#   openjdk            conda-forge/osx-64::openjdk-17.0.3-hfa58983_1
#   openjpeg           conda-forge/osx-64::openjpeg-2.4.0-h6e7aa92_1
#   openssl            conda-forge/osx-64::openssl-1.1.1q-hfe4f2af_0
#   packaging          conda-forge/noarch::packaging-21.3-pyhd8ed1ab_0
#   pandas             conda-forge/osx-64::pandas-1.3.4-py37h5b83a90_1
#   pandoc             conda-forge/osx-64::pandoc-2.18-h694c41f_0
#   pandocfilters      conda-forge/noarch::pandocfilters-1.5.0-pyhd8ed1ab_0
#   pango              conda-forge/osx-64::pango-1.50.8-he4563bb_1
#   parso              conda-forge/noarch::parso-0.8.3-pyhd8ed1ab_0
#   pbzip2             conda-forge/osx-64::pbzip2-1.1.13-h9d27c22_1
#   pcre               conda-forge/osx-64::pcre-8.45-he49afe7_0
#   pcre2              conda-forge/osx-64::pcre2-10.37-ha16e1b2_0
#   perl               conda-forge/osx-64::perl-5.32.1-2_h0d85af4_perl5
#   perl-apache-test   bioconda/noarch::perl-apache-test-1.43-pl5321hdfd78af_0
#   perl-app-cpanminus conda-forge/noarch::perl-app-cpanminus-1.7046-pl5321hd8ed1ab_0
#   perl-archive-tar   bioconda/noarch::perl-archive-tar-2.40-pl5321hdfd78af_0
#   perl-autoloader    bioconda/noarch::perl-autoloader-5.74-pl5321hdfd78af_3
#   perl-base          bioconda/noarch::perl-base-2.23-pl5321hdfd78af_2
#   perl-carp          conda-forge/noarch::perl-carp-1.50-pl5321hd8ed1ab_0
#   perl-class-load    bioconda/noarch::perl-class-load-0.25-pl5321hdfd78af_1
#   perl-class-load-xs bioconda/osx-64::perl-class-load-xs-0.10-pl5321hcd10b59_6
#   perl-class-method~ bioconda/noarch::perl-class-method-modifiers-2.13-pl5321hdfd78af_0
#   perl-clone         bioconda/osx-64::perl-clone-0.42-pl5321ha5712d3_2
#   perl-common-sense  bioconda/noarch::perl-common-sense-3.75-pl5321hdfd78af_0
#   perl-compress-raw~ bioconda/osx-64::perl-compress-raw-bzip2-2.201-pl5321h9722bc1_0
#   perl-compress-raw~ bioconda/osx-64::perl-compress-raw-zlib-2.105-pl5321h9722bc1_0
#   perl-config-gener~ bioconda/noarch::perl-config-general-2.65-pl5321hdfd78af_0
#   perl-constant      conda-forge/noarch::perl-constant-1.33-pl5321hd8ed1ab_0
#   perl-cpan-meta     bioconda/noarch::perl-cpan-meta-2.150010-pl5321hdfd78af_1
#   perl-cpan-meta-re~ bioconda/noarch::perl-cpan-meta-requirements-2.140-pl5321hdfd78af_1
#   perl-cpan-meta-ya~ bioconda/noarch::perl-cpan-meta-yaml-0.018-pl5321hdfd78af_1
#   perl-data-dumper   bioconda/osx-64::perl-data-dumper-2.183-pl5321ha5712d3_1
#   perl-data-optlist  bioconda/noarch::perl-data-optlist-0.112-pl5321hdfd78af_0
#   perl-dbi           bioconda/osx-64::perl-dbi-1.643-pl5321ha5712d3_1
#   perl-devel-global~ bioconda/noarch::perl-devel-globaldestruction-0.14-pl5321hdfd78af_1
#   perl-devel-overlo~ bioconda/noarch::perl-devel-overloadinfo-0.007-pl5321hdfd78af_0
#   perl-devel-stackt~ bioconda/noarch::perl-devel-stacktrace-2.04-pl5321hdfd78af_1
#   perl-digest-perl-~ bioconda/noarch::perl-digest-perl-md5-1.9-pl5321hdfd78af_2
#   perl-dist-checkco~ bioconda/noarch::perl-dist-checkconflicts-0.11-pl5321hdfd78af_3
#   perl-dynaloader    bioconda/noarch::perl-dynaloader-1.25-pl5321hdfd78af_2
#   perl-encode        bioconda/osx-64::perl-encode-3.18-pl5321ha5712d3_0
#   perl-eval-closure  bioconda/osx-64::perl-eval-closure-0.14-pl5321hcd10b59_6
#   perl-exporter      conda-forge/noarch::perl-exporter-5.74-pl5321hd8ed1ab_0
#   perl-exporter-tiny bioconda/noarch::perl-exporter-tiny-1.002002-pl5321hdfd78af_0
#   perl-extutils-cbu~ bioconda/noarch::perl-extutils-cbuilder-0.280230-pl5321hdfd78af_2
#   perl-extutils-mak~ conda-forge/noarch::perl-extutils-makemaker-7.64-pl5321hd8ed1ab_0
#   perl-extutils-man~ bioconda/noarch::perl-extutils-manifest-1.73-pl5321hdfd78af_0
#   perl-extutils-par~ bioconda/noarch::perl-extutils-parsexs-3.44-pl5321hdfd78af_0
#   perl-file-path     conda-forge/noarch::perl-file-path-2.18-pl5321hd8ed1ab_0
#   perl-file-temp     conda-forge/noarch::perl-file-temp-0.2304-pl5321hd8ed1ab_0
#   perl-file-which    conda-forge/noarch::perl-file-which-1.24-pl5321hd8ed1ab_0
#   perl-filesys-df    bioconda/osx-64::perl-filesys-df-0.92-pl5321ha5712d3_5
#   perl-font-ttf      bioconda/noarch::perl-font-ttf-1.06-pl5321hdfd78af_1
#   perl-gd            bioconda/osx-64::perl-gd-2.76-pl5321hb8176d5_1
#   perl-getopt-long   bioconda/noarch::perl-getopt-long-2.52-pl5321hdfd78af_0
#   perl-io-compress   bioconda/osx-64::perl-io-compress-2.106-pl5321h9722bc1_0
#   perl-io-string     bioconda/noarch::perl-io-string-1.08-pl5321hdfd78af_4
#   perl-io-zlib       bioconda/noarch::perl-io-zlib-1.11-pl5321hdfd78af_0
#   perl-ipc-cmd       bioconda/noarch::perl-ipc-cmd-1.04-pl5321hdfd78af_0
#   perl-json          bioconda/noarch::perl-json-4.09-pl5321hdfd78af_0
#   perl-json-pp       bioconda/noarch::perl-json-pp-4.11-pl5321hdfd78af_0
#   perl-json-xs       bioconda/osx-64::perl-json-xs-2.34-pl5321hcd10b59_5
#   perl-list-moreuti~ bioconda/noarch::perl-list-moreutils-0.430-pl5321hdfd78af_0
#   perl-list-moreuti~ bioconda/osx-64::perl-list-moreutils-xs-0.430-pl5321ha5712d3_1
#   perl-locale-maket~ bioconda/noarch::perl-locale-maketext-simple-0.21-pl5321hdfd78af_3
#   perl-math-bezier   bioconda/noarch::perl-math-bezier-0.01-pl5321hdfd78af_2
#   perl-math-round    bioconda/noarch::perl-math-round-0.07-pl5321hdfd78af_2
#   perl-math-vecstat  bioconda/noarch::perl-math-vecstat-0.08-pl5321hdfd78af_2
#   perl-module-build  bioconda/noarch::perl-module-build-0.4231-pl5321hdfd78af_0
#   perl-module-corel~ bioconda/noarch::perl-module-corelist-5.20220620-pl5321hdfd78af_0
#   perl-module-imple~ bioconda/noarch::perl-module-implementation-0.09-pl5321hdfd78af_3
#   perl-module-load   bioconda/noarch::perl-module-load-0.34-pl5321hdfd78af_0
#   perl-module-load-~ bioconda/noarch::perl-module-load-conditional-0.68-pl5321hdfd78af_3
#   perl-module-metad~ bioconda/noarch::perl-module-metadata-1.000037-pl5321hdfd78af_0
#   perl-module-runti~ bioconda/noarch::perl-module-runtime-0.016-pl5321hdfd78af_2
#   perl-module-runti~ bioconda/noarch::perl-module-runtime-conflicts-0.003-pl5321hdfd78af_1
#   perl-moo           bioconda/noarch::perl-moo-2.005004-pl5321hdfd78af_0
#   perl-moose         bioconda/osx-64::perl-moose-2.2201-pl5321ha5712d3_2
#   perl-mro-compat    bioconda/noarch::perl-mro-compat-0.15-pl5321hdfd78af_0
#   perl-number-format bioconda/noarch::perl-number-format-1.75-pl5321hdfd78af_4
#   perl-package-depr~ bioconda/noarch::perl-package-deprecationmanager-0.17-pl5321hdfd78af_1
#   perl-package-stash bioconda/osx-64::perl-package-stash-0.40-pl5321h9722bc1_1
#   perl-package-stas~ bioconda/osx-64::perl-package-stash-xs-0.29-pl5321h9722bc1_1
#   perl-parallel-for~ bioconda/noarch::perl-parallel-forkmanager-2.02-pl5321hdfd78af_1
#   perl-params-check  bioconda/noarch::perl-params-check-0.38-pl5321hdfd78af_2
#   perl-params-util   bioconda/osx-64::perl-params-util-1.102-pl5321hcd10b59_1
#   perl-params-valid~ bioconda/osx-64::perl-params-validate-1.30-pl5321ha5712d3_1
#   perl-parent        conda-forge/noarch::perl-parent-0.238-pl5321hd8ed1ab_0
#   perl-pathtools     bioconda/osx-64::perl-pathtools-3.75-pl5321ha5712d3_3
#   perl-perl-ostype   bioconda/noarch::perl-perl-ostype-1.010-pl5321hdfd78af_2
#   perl-readonly      bioconda/noarch::perl-readonly-2.05-pl5321hdfd78af_1
#   perl-regexp-common bioconda/noarch::perl-regexp-common-2017060201-pl5321hdfd78af_1
#   perl-role-tiny     bioconda/noarch::perl-role-tiny-2.002004-pl5321hdfd78af_0
#   perl-scalar-list-~ bioconda/osx-64::perl-scalar-list-utils-1.62-pl5321ha5712d3_0
#   perl-set-intspan   bioconda/noarch::perl-set-intspan-1.19-pl5321hdfd78af_2
#   perl-statistics-b~ bioconda/noarch::perl-statistics-basic-1.6611-pl5321hdfd78af_3
#   perl-storable      bioconda/osx-64::perl-storable-3.15-pl5321ha5712d3_3
#   perl-sub-exporter  bioconda/noarch::perl-sub-exporter-0.988-pl5321hdfd78af_0
#   perl-sub-exporter~ bioconda/noarch::perl-sub-exporter-progressive-0.001013-pl5321hdfd78af_1
#   perl-sub-identify  bioconda/osx-64::perl-sub-identify-0.14-pl5321ha5712d3_2
#   perl-sub-install   bioconda/noarch::perl-sub-install-0.928-pl5321hdfd78af_3
#   perl-sub-name      bioconda/osx-64::perl-sub-name-0.21-pl5321ha5712d3_3
#   perl-sub-quote     bioconda/noarch::perl-sub-quote-2.006006-pl5321hdfd78af_0
#   perl-svg           bioconda/noarch::perl-svg-2.87-pl5321hdfd78af_0
#   perl-text-abbrev   bioconda/noarch::perl-text-abbrev-1.02-pl5321hdfd78af_1
#   perl-text-format   bioconda/noarch::perl-text-format-0.62-pl5321hdfd78af_0
#   perl-text-parsewo~ bioconda/noarch::perl-text-parsewords-3.31-pl5321hdfd78af_0
#   perl-time-hires    bioconda/osx-64::perl-time-hires-1.9764-pl5321ha5712d3_2
#   perl-try-tiny      bioconda/noarch::perl-try-tiny-0.31-pl5321hdfd78af_0
#   perl-types-serial~ bioconda/noarch::perl-types-serialiser-1.01-pl5321hdfd78af_0
#   perl-version       bioconda/osx-64::perl-version-0.9924-pl5321ha5712d3_2
#   perl-xml-parser    conda-forge/osx-64::perl-xml-parser-2.44_01-pl5321h06ef574_1003
#   perl-xsloader      conda-forge/noarch::perl-xsloader-0.24-pl5321hd8ed1ab_0
#   perl-yaml          bioconda/noarch::perl-yaml-1.30-pl5321hdfd78af_0
#   pexpect            conda-forge/noarch::pexpect-4.8.0-pyh9f0ad1d_2
#   pickleshare        conda-forge/noarch::pickleshare-0.7.5-py_1003
#   pillow             conda-forge/osx-64::pillow-9.2.0-py37h1eb1bbc_0
#   pip                conda-forge/noarch::pip-22.2.1-pyhd8ed1ab_0
#   pixman             conda-forge/osx-64::pixman-0.40.0-hbcb3906_0
#   pkgutil-resolve-n~ conda-forge/noarch::pkgutil-resolve-name-1.3.10-pyhd8ed1ab_0
#   ply                conda-forge/noarch::ply-3.11-py_1
#   prodigal           bioconda/osx-64::prodigal-2.6.3-ha5712d3_4
#   prometheus_client  conda-forge/noarch::prometheus_client-0.14.1-pyhd8ed1ab_0
#   prompt-toolkit     conda-forge/noarch::prompt-toolkit-3.0.30-pyha770c72_0
#   prompt_toolkit     conda-forge/noarch::prompt_toolkit-3.0.30-hd8ed1ab_0
#   psutil             conda-forge/osx-64::psutil-5.9.1-py37h994c40b_0
#   pthread-stubs      conda-forge/osx-64::pthread-stubs-0.4-hc929b4f_1001
#   ptyprocess         conda-forge/noarch::ptyprocess-0.7.0-pyhd3deb0d_0
#   pycparser          conda-forge/noarch::pycparser-2.21-pyhd8ed1ab_0
#   pygments           conda-forge/noarch::pygments-2.12.0-pyhd8ed1ab_0
#   pyparsing          conda-forge/noarch::pyparsing-3.0.9-pyhd8ed1ab_0
#   pyqt               conda-forge/osx-64::pyqt-5.15.7-py37h6d02c96_0
#   pyqt5-sip          conda-forge/osx-64::pyqt5-sip-12.11.0-py37h453a0d4_0
#   pyrsistent         conda-forge/osx-64::pyrsistent-0.18.1-py37h69ee0a8_1
#   python             conda-forge/osx-64::python-3.7.12-haf480d7_100_cpython
#   python-dateutil    conda-forge/noarch::python-dateutil-2.8.2-pyhd8ed1ab_0
#   python-fastjsonsc~ conda-forge/noarch::python-fastjsonschema-2.16.1-pyhd8ed1ab_0
#   python_abi         conda-forge/osx-64::python_abi-3.7-2_cp37m
#   pytz               conda-forge/noarch::pytz-2022.1-pyhd8ed1ab_0
#   pyzmq              conda-forge/osx-64::pyzmq-23.2.0-py37h573e605_0
#   qt-main            conda-forge/osx-64::qt-main-5.15.4-h938c29d_2
#   qtconsole          conda-forge/noarch::qtconsole-5.3.1-pyhd8ed1ab_0
#   qtconsole-base     conda-forge/noarch::qtconsole-base-5.3.1-pyha770c72_0
#   qtpy               conda-forge/noarch::qtpy-2.1.0-pyhd8ed1ab_0
#   quast              bioconda/osx-64::quast-5.2.0-py37pl5321h02f24ee_1
#   r-backports        conda-forge/osx-64::r-backports-1.4.1-r41h28b5c78_0
#   r-base             conda-forge/osx-64::r-base-4.1.3-h234e2ac_1
#   r-brio             conda-forge/osx-64::r-brio-1.1.3-r41h28b5c78_0
#   r-callr            conda-forge/noarch::r-callr-3.7.1-r41hc72bb7e_0
#   r-cli              conda-forge/osx-64::r-cli-3.3.0-r41h8619c4b_0
#   r-colorspace       conda-forge/osx-64::r-colorspace-2.0_3-r41h0f1d5c4_0
#   r-crayon           conda-forge/noarch::r-crayon-1.5.1-r41hc72bb7e_0
#   r-desc             conda-forge/noarch::r-desc-1.4.1-r41hc72bb7e_0
#   r-diffobj          conda-forge/osx-64::r-diffobj-0.3.5-r41h28b5c78_0
#   r-digest           conda-forge/osx-64::r-digest-0.6.29-r41h9951f98_0
#   r-ellipsis         conda-forge/osx-64::r-ellipsis-0.3.2-r41h28b5c78_0
#   r-evaluate         conda-forge/noarch::r-evaluate-0.15-r41hc72bb7e_0
#   r-fansi            conda-forge/osx-64::r-fansi-1.0.3-r41h0f1d5c4_0
#   r-farver           conda-forge/osx-64::r-farver-2.1.1-r41h8619c4b_0
#   r-fs               conda-forge/osx-64::r-fs-1.5.2-r41hc4bb905_1
#   r-ggplot2          conda-forge/noarch::r-ggplot2-3.3.6-r41hc72bb7e_0
#   r-glue             conda-forge/osx-64::r-glue-1.6.2-r41h0f1d5c4_0
#   r-gtable           conda-forge/noarch::r-gtable-0.3.0-r41hc72bb7e_3
#   r-isoband          conda-forge/osx-64::r-isoband-0.2.5-r41h9951f98_0
#   r-jsonlite         conda-forge/osx-64::r-jsonlite-1.8.0-r41h0f1d5c4_0
#   r-labeling         conda-forge/noarch::r-labeling-0.4.2-r41hc72bb7e_1
#   r-lattice          conda-forge/osx-64::r-lattice-0.20_45-r41h28b5c78_0
#   r-lifecycle        conda-forge/noarch::r-lifecycle-1.0.1-r41hc72bb7e_0
#   r-magrittr         conda-forge/osx-64::r-magrittr-2.0.3-r41h0f1d5c4_0
#   r-mass             conda-forge/osx-64::r-mass-7.3_58-r41h67d6963_0
#   r-matrix           conda-forge/osx-64::r-matrix-1.4_1-r41ha2825d1_0
#   r-mgcv             conda-forge/osx-64::r-mgcv-1.8_40-r41h60b693f_0
# ...
#   prefix=/opt/anaconda3/envs/curso
#   source=/opt/anaconda3/pkgs/argon2-cffi-21.3.0-pyhd8ed1ab_0
#
#
# ===> LINKING PACKAGE: conda-forge::biopython-1.79-py37h69ee0a8_2 <===
#   prefix=/opt/anaconda3/envs/curso
#   source=/opt/anaconda3/pkgs/biopython-1.79-py37h69ee0a8_2
#
#
# ===> LINKING PACKAGE: bioconda::circos-0.69.8-hdfd78af_1 <===
#   prefix=/opt/anaconda3/envs/curso
#   source=/opt/anaconda3/pkgs/circos-0.69.8-hdfd78af_1
#
#
# ===> LINKING PACKAGE: defaults::compiler-rt_osx-64-12.0.0-hfb26b64_2 <===
#   prefix=/opt/anaconda3/envs/curso
#   source=/opt/anaconda3/pkgs/compiler-rt_osx-64-12.0.0-hfb26b64_2
#
#
# ===> LINKING PACKAGE: conda-forge::jupyterlab_pygments-0.2.2-pyhd8ed1ab_0 <===
#   prefix=/opt/anaconda3/envs/curso
#   source=/opt/anaconda3/pkgs/jupyterlab_pygments-0.2.2-pyhd8ed1ab_0
#
#
# ===> LINKING PACKAGE: conda-forge::matplotlib-base-3.5.2-py37h80cb303_1 <===
#   prefix=/opt/anaconda3/envs/curso
#   source=/opt/anaconda3/pkgs/matplotlib-base-3.5.2-py37h80cb303_1
#
#
# ===> LINKING PACKAGE: conda-forge::nbformat-5.4.0-pyhd8ed1ab_0 <===
#   prefix=/opt/anaconda3/envs/curso
#   source=/opt/anaconda3/pkgs/nbformat-5.4.0-pyhd8ed1ab_0
#
#
# ===> LINKING PACKAGE: conda-forge::pandas-1.3.4-py37h5b83a90_1 <===
#   prefix=/opt/anaconda3/envs/curso
#   source=/opt/anaconda3/pkgs/pandas-1.3.4-py37h5b83a90_1
#
#
# ===> LINKING PACKAGE: conda-forge::pango-1.50.8-he4563bb_1 <===
#   prefix=/opt/anaconda3/envs/curso
#   source=/opt/anaconda3/pkgs/pango-1.50.8-he4563bb_1
#
#
# ===> LINKING PACKAGE: bioconda::perl-class-load-xs-0.10-pl5321hcd10b59_6 <===
#   prefix=/opt/anaconda3/envs/curso
#   source=/opt/anaconda3/pkgs/perl-class-load-xs-0.10-pl5321hcd10b59_6
#
#
# ===> LINKING PACKAGE: bioconda::perl-extutils-parsexs-3.44-pl5321hdfd78af_0 <===
#   prefix=/opt/anaconda3/envs/curso
#   source=/opt/anaconda3/pkgs/perl-extutils-parsexs-3.44-pl5321hdfd78af_0
#
#
# ===> LINKING PACKAGE: conda-forge::pyqt5-sip-12.11.0-py37h453a0d4_0 <===
#   prefix=/opt/anaconda3/envs/curso
#   source=/opt/anaconda3/pkgs/pyqt5-sip-12.11.0-py37h453a0d4_0
#
#
# ===> LINKING PACKAGE: conda-forge::qt-main-5.15.4-h938c29d_2 <===
#   prefix=/opt/anaconda3/envs/curso
#   source=/opt/anaconda3/pkgs/qt-main-5.15.4-h938c29d_2
#
#
# ===> LINKING PACKAGE: conda-forge::wcwidth-0.2.5-pyh9f0ad1d_2 <===
#   prefix=/opt/anaconda3/envs/curso
#   source=/opt/anaconda3/pkgs/wcwidth-0.2.5-pyh9f0ad1d_2
#
#
# ===> LINKING PACKAGE: defaults::compiler-rt-12.0.0-hd87ff74_2 <===
#   prefix=/opt/anaconda3/envs/curso
#   source=/opt/anaconda3/pkgs/compiler-rt-12.0.0-hd87ff74_2
#
#
# ===> LINKING PACKAGE: conda-forge::gnuplot-5.4.4-h8cdca01_0 <===
#   prefix=/opt/anaconda3/envs/curso
#   source=/opt/anaconda3/pkgs/gnuplot-5.4.4-h8cdca01_0
#
#
# ===> LINKING PACKAGE: bioconda::nanopolish-0.14.0-h7d00a20_0 <===
#   prefix=/opt/anaconda3/envs/curso
#   source=/opt/anaconda3/pkgs/nanopolish-0.14.0-h7d00a20_0
#
#
# ===> LINKING PACKAGE: conda-forge::nbclient-0.6.6-pyhd8ed1ab_0 <===
#   prefix=/opt/anaconda3/envs/curso
#   source=/opt/anaconda3/pkgs/nbclient-0.6.6-pyhd8ed1ab_0
#
#
# ===> LINKING PACKAGE: bioconda::perl-module-build-0.4231-pl5321hdfd78af_0 <===
#   prefix=/opt/anaconda3/envs/curso
#   source=/opt/anaconda3/pkgs/perl-module-build-0.4231-pl5321hdfd78af_0
#
#
# ===> LINKING PACKAGE: bioconda::perl-moose-2.2201-pl5321ha5712d3_2 <===
#   prefix=/opt/anaconda3/envs/curso
#   source=/opt/anaconda3/pkgs/perl-moose-2.2201-pl5321ha5712d3_2
#
#
# ===> LINKING PACKAGE: conda-forge::prompt-toolkit-3.0.30-pyha770c72_0 <===
#   prefix=/opt/anaconda3/envs/curso
#   source=/opt/anaconda3/pkgs/prompt-toolkit-3.0.30-pyha770c72_0
# ===> LINKING PACKAGE: conda-forge::pyqt-5.15.7-py37h6d02c96_0 <===
#   prefix=/opt/anaconda3/envs/curso
#   source=/opt/anaconda3/pkgs/pyqt-5.15.7-py37h6d02c96_0
#
#
# ===> LINKING PACKAGE: bioconda::quast-5.2.0-py37pl5321h02f24ee_1 <===
#   prefix=/opt/anaconda3/envs/curso
#   source=/opt/anaconda3/pkgs/quast-5.2.0-py37pl5321h02f24ee_1
#
#
# ===> LINKING PACKAGE: bioconda::canu-2.2-hbe63672_0 <===
#   prefix=/opt/anaconda3/envs/curso
#   source=/opt/anaconda3/pkgs/canu-2.2-hbe63672_0
#
#
# file exists, but clobbering: '/opt/anaconda3/envs/curso/lib/libgcc_s.1.dylib'
#
# file exists, but clobbering: '/opt/anaconda3/envs/curso/lib/libgomp.1.dylib'
#
# ===> LINKING PACKAGE: defaults::clang_osx-64-12.0.0-h7ad7729_2 <===
#   prefix=/opt/anaconda3/envs/curso
#   source=/opt/anaconda3/pkgs/clang_osx-64-12.0.0-h7ad7729_2
#
#
# ===> LINKING PACKAGE: conda-forge::ipython-7.33.0-py37hf985489_0 <===
#   prefix=/opt/anaconda3/envs/curso
#   source=/opt/anaconda3/pkgs/ipython-7.33.0-py37hf985489_0
#
#
# ===> LINKING PACKAGE: conda-forge::nbconvert-core-6.5.0-pyhd8ed1ab_0 <===
#   prefix=/opt/anaconda3/envs/curso
#   source=/opt/anaconda3/pkgs/nbconvert-core-6.5.0-pyhd8ed1ab_0
#
#
# ===> LINKING PACKAGE: bioconda::perl-moo-2.005004-pl5321hdfd78af_0 <===
#   prefix=/opt/anaconda3/envs/curso
#   source=/opt/anaconda3/pkgs/perl-moo-2.005004-pl5321hdfd78af_0
#
#
# ===> LINKING PACKAGE: conda-forge::prompt_toolkit-3.0.30-hd8ed1ab_0 <===
#   prefix=/opt/anaconda3/envs/curso
#   source=/opt/anaconda3/pkgs/prompt_toolkit-3.0.30-hd8ed1ab_0
#
#
# ===> LINKING PACKAGE: defaults::clangxx_osx-64-12.0.0-he0c6f94_2 <===
#   prefix=/opt/anaconda3/envs/curso
#   source=/opt/anaconda3/pkgs/clangxx_osx-64-12.0.0-he0c6f94_2
#
#
# ===> LINKING PACKAGE: conda-forge::gfortran_osx-64-9.3.0-h18f7dce_15 <===
#   prefix=/opt/anaconda3/envs/curso
#   source=/opt/anaconda3/pkgs/gfortran_osx-64-9.3.0-h18f7dce_15
#
#
# ===> LINKING PACKAGE: conda-forge::ipykernel-6.15.1-pyh736e0ef_0 <===
#   prefix=/opt/anaconda3/envs/curso
#   source=/opt/anaconda3/pkgs/ipykernel-6.15.1-pyh736e0ef_0
#
#
# ===> LINKING PACKAGE: conda-forge::nbconvert-pandoc-6.5.0-pyhd8ed1ab_0 <===
#   prefix=/opt/anaconda3/envs/curso
#   source=/opt/anaconda3/pkgs/nbconvert-pandoc-6.5.0-pyhd8ed1ab_0
#
#
# ===> LINKING PACKAGE: bioconda::perl-parallel-forkmanager-2.02-pl5321hdfd78af_1 <===
#   prefix=/opt/anaconda3/envs/curso
#   source=/opt/anaconda3/pkgs/perl-parallel-forkmanager-2.02-pl5321hdfd78af_1
#
#
# ===> LINKING PACKAGE: bioconda::augustus-3.4.0-pl5321he8e39e9_6 <===
#   prefix=/opt/anaconda3/envs/curso
#   source=/opt/anaconda3/pkgs/augustus-3.4.0-pl5321he8e39e9_6
#
#
# ===> LINKING PACKAGE: conda-forge::jupyter_console-6.4.4-pyhd8ed1ab_0 <===
#   prefix=/opt/anaconda3/envs/curso
#   source=/opt/anaconda3/pkgs/jupyter_console-6.4.4-pyhd8ed1ab_0
#
#
# ===> LINKING PACKAGE: conda-forge::nbconvert-6.5.0-pyhd8ed1ab_0 <===
#   prefix=/opt/anaconda3/envs/curso
#   source=/opt/anaconda3/pkgs/nbconvert-6.5.0-pyhd8ed1ab_0
#
#
# ===> LINKING PACKAGE: conda-forge::qtconsole-base-5.3.1-pyha770c72_0 <===
#   prefix=/opt/anaconda3/envs/curso
#   source=/opt/anaconda3/pkgs/qtconsole-base-5.3.1-pyha770c72_0
#
#
# ===> LINKING PACKAGE: conda-forge::r-base-4.1.3-h234e2ac_1 <===
#   prefix=/opt/anaconda3/envs/curso
#   source=/opt/anaconda3/pkgs/r-base-4.1.3-h234e2ac_1
#
#
# ===> LINKING PACKAGE: conda-forge::notebook-6.4.12-pyha770c72_0 <===
#   prefix=/opt/anaconda3/envs/curso
#   source=/opt/anaconda3/pkgs/notebook-6.4.12-pyha770c72_0
#
#
# ===> LINKING PACKAGE: conda-forge::qtconsole-5.3.1-pyhd8ed1ab_0 <===
#   prefix=/opt/anaconda3/envs/curso
#   source=/opt/anaconda3/pkgs/qtconsole-5.3.1-pyhd8ed1ab_0
#
#
# ===> LINKING PACKAGE: conda-forge::r-backports-1.4.1-r41h28b5c78_0 <===
#   prefix=/opt/anaconda3/envs/curso
#   source=/opt/anaconda3/pkgs/r-backports-1.4.1-r41h28b5c78_0
#
#
# ===> LINKING PACKAGE: conda-forge::r-brio-1.1.3-r41h28b5c78_0 <===
#   prefix=/opt/anaconda3/envs/curso
#   source=/opt/anaconda3/pkgs/r-brio-1.1.3-r41h28b5c78_0
#
#
# ===> LINKING PACKAGE: conda-forge::r-colorspace-2.0_3-r41h0f1d5c4_0 <===
#   prefix=/opt/anaconda3/envs/curso
#   source=/opt/anaconda3/pkgs/r-colorspace-2.0_3-r41h0f1d5c4_0
#
#
# ===> LINKING PACKAGE: conda-forge::r-crayon-1.5.1-r41hc72bb7e_0 <===
#   prefix=/opt/anaconda3/envs/curso
#   source=/opt/anaconda3/pkgs/r-crayon-1.5.1-r41hc72bb7e_0
#
#
# ===> LINKING PACKAGE: conda-forge::r-digest-0.6.29-r41h9951f98_0 <===
#   prefix=/opt/anaconda3/envs/curso
#   source=/opt/anaconda3/pkgs/r-digest-0.6.29-r41h9951f98_0
#
#
# ===> LINKING PACKAGE: conda-forge::r-evaluate-0.15-r41hc72bb7e_0 <===
#   prefix=/opt/anaconda3/envs/curso
#   source=/opt/anaconda3/pkgs/r-evaluate-0.15-r41hc72bb7e_0
#
#
# ===> LINKING PACKAGE: conda-forge::r-fansi-1.0.3-r41h0f1d5c4_0 <===
#   prefix=/opt/anaconda3/envs/curso
#   source=/opt/anaconda3/pkgs/r-fansi-1.0.3-r41h0f1d5c4_0
#
#
# ===> LINKING PACKAGE: conda-forge::r-farver-2.1.1-r41h8619c4b_0 <===
#   prefix=/opt/anaconda3/envs/curso
#   source=/opt/anaconda3/pkgs/r-farver-2.1.1-r41h8619c4b_0
#
#
# ===> LINKING PACKAGE: conda-forge::r-fs-1.5.2-r41hc4bb905_1 <===
#   prefix=/opt/anaconda3/envs/curso
#   source=/opt/anaconda3/pkgs/r-fs-1.5.2-r41hc4bb905_1
#
#
# ===> LINKING PACKAGE: conda-forge::r-glue-1.6.2-r41h0f1d5c4_0 <===
#   prefix=/opt/anaconda3/envs/curso
#   source=/opt/anaconda3/pkgs/r-glue-1.6.2-r41h0f1d5c4_0
#
#
# ===> LINKING PACKAGE: conda-forge::r-gtable-0.3.0-r41hc72bb7e_3 <===
#   prefix=/opt/anaconda3/envs/curso
#   source=/opt/anaconda3/pkgs/r-gtable-0.3.0-r41hc72bb7e_3
#
#
# ===> LINKING PACKAGE: conda-forge::r-jsonlite-1.8.0-r41h0f1d5c4_0 <===
#   prefix=/opt/anaconda3/envs/curso
#   source=/opt/anaconda3/pkgs/r-jsonlite-1.8.0-r41h0f1d5c4_0
#
#
# ===> LINKING PACKAGE: conda-forge::r-labeling-0.4.2-r41hc72bb7e_1 <===
#   prefix=/opt/anaconda3/envs/curso
#   source=/opt/anaconda3/pkgs/r-labeling-0.4.2-r41hc72bb7e_1
#
#
# ===> LINKING PACKAGE: conda-forge::r-lattice-0.20_45-r41h28b5c78_0 <===
#   prefix=/opt/anaconda3/envs/curso
#   source=/opt/anaconda3/pkgs/r-lattice-0.20_45-r41h28b5c78_0
#
#
# ===> LINKING PACKAGE: conda-forge::r-magrittr-2.0.3-r41h0f1d5c4_0 <===
#   prefix=/opt/anaconda3/envs/curso
#   source=/opt/anaconda3/pkgs/r-magrittr-2.0.3-r41h0f1d5c4_0
#
#
# ===> LINKING PACKAGE: conda-forge::r-mass-7.3_58-r41h67d6963_0 <===
#   prefix=/opt/anaconda3/envs/curso
#   source=/opt/anaconda3/pkgs/r-mass-7.3_58-r41h67d6963_0
#
#
# ===> LINKING PACKAGE: conda-forge::r-pkgconfig-2.0.3-r41hc72bb7e_1 <===
#   prefix=/opt/anaconda3/envs/curso
#   source=/opt/anaconda3/pkgs/r-pkgconfig-2.0.3-r41hc72bb7e_1
#
#
# ===> LINKING PACKAGE: conda-forge::r-praise-1.0.0-r41hc72bb7e_1005 <===
#   prefix=/opt/anaconda3/envs/curso
#   source=/opt/anaconda3/pkgs/r-praise-1.0.0-r41hc72bb7e_1005
#
#
# ===> LINKING PACKAGE: conda-forge::r-ps-1.7.1-r41h67d6963_0 <===
#   prefix=/opt/anaconda3/envs/curso
#   source=/opt/anaconda3/pkgs/r-ps-1.7.1-r41h67d6963_0
#
#
# ===> LINKING PACKAGE: conda-forge::r-r6-2.5.1-r41hc72bb7e_0 <===
#   prefix=/opt/anaconda3/envs/curso
#   source=/opt/anaconda3/pkgs/r-r6-2.5.1-r41hc72bb7e_0
#
#
# ===> LINKING PACKAGE: conda-forge::r-rcolorbrewer-1.1_3-r41h785f33e_0 <===
#   prefix=/opt/anaconda3/envs/curso
#   source=/opt/anaconda3/pkgs/r-rcolorbrewer-1.1_3-r41h785f33e_0
#
#
# ===> LINKING PACKAGE: conda-forge::r-rcpp-1.0.9-r41h8619c4b_0 <===
#   prefix=/opt/anaconda3/envs/curso
#   source=/opt/anaconda3/pkgs/r-rcpp-1.0.9-r41h8619c4b_0
#
#
# ===> LINKING PACKAGE: conda-forge::r-rlang-1.0.4-r41h8619c4b_0 <===
#   prefix=/opt/anaconda3/envs/curso
#   source=/opt/anaconda3/pkgs/r-rlang-1.0.4-r41h8619c4b_0
#
#
# ===> LINKING PACKAGE: conda-forge::r-utf8-1.2.2-r41h28b5c78_0 <===
#   prefix=/opt/anaconda3/envs/curso
#   source=/opt/anaconda3/pkgs/r-utf8-1.2.2-r41h28b5c78_0
#
#
# ===> LINKING PACKAGE: conda-forge::r-viridislite-0.4.0-r41hc72bb7e_0 <===
#   prefix=/opt/anaconda3/envs/curso
#   source=/opt/anaconda3/pkgs/r-viridislite-0.4.0-r41hc72bb7e_0
#
#
# ===> LINKING PACKAGE: conda-forge::r-withr-2.5.0-r41hc72bb7e_0 <===
#   prefix=/opt/anaconda3/envs/curso
#   source=/opt/anaconda3/pkgs/r-withr-2.5.0-r41hc72bb7e_0
#
#
# ===> LINKING PACKAGE: conda-forge::r-cli-3.3.0-r41h8619c4b_0 <===
#   prefix=/opt/anaconda3/envs/curso
#   source=/opt/anaconda3/pkgs/r-cli-3.3.0-r41h8619c4b_0
#
#
# ===> LINKING PACKAGE: conda-forge::r-diffobj-0.3.5-r41h28b5c78_0 <===
#   prefix=/opt/anaconda3/envs/curso
#   source=/opt/anaconda3/pkgs/r-diffobj-0.3.5-r41h28b5c78_0
#
#
# ===> LINKING PACKAGE: conda-forge::r-ellipsis-0.3.2-r41h28b5c78_0 <===
#   prefix=/opt/anaconda3/envs/curso
#   source=/opt/anaconda3/pkgs/r-ellipsis-0.3.2-r41h28b5c78_0
#
#
# ===> LINKING PACKAGE: conda-forge::r-lifecycle-1.0.1-r41hc72bb7e_0 <===
#   prefix=/opt/anaconda3/envs/curso
#   source=/opt/anaconda3/pkgs/r-lifecycle-1.0.1-r41hc72bb7e_0
# ===> LINKING PACKAGE: conda-forge::r-matrix-1.4_1-r41ha2825d1_0 <===
#   prefix=/opt/anaconda3/envs/curso
#   source=/opt/anaconda3/pkgs/r-matrix-1.4_1-r41ha2825d1_0
#
#
# ===> LINKING PACKAGE: conda-forge::r-munsell-0.5.0-r41hc72bb7e_1004 <===
#   prefix=/opt/anaconda3/envs/curso
#   source=/opt/anaconda3/pkgs/r-munsell-0.5.0-r41hc72bb7e_1004
#
#
# ===> LINKING PACKAGE: conda-forge::r-nlme-3.1_158-r41he3b5f32_0 <===
#   prefix=/opt/anaconda3/envs/curso
#   source=/opt/anaconda3/pkgs/r-nlme-3.1_158-r41he3b5f32_0
#
#
# ===> LINKING PACKAGE: conda-forge::r-processx-3.7.0-r41h67d6963_0 <===
#   prefix=/opt/anaconda3/envs/curso
#   source=/opt/anaconda3/pkgs/r-processx-3.7.0-r41h67d6963_0
#
#
# ===> LINKING PACKAGE: conda-forge::r-rprojroot-2.0.3-r41hc72bb7e_0 <===
#   prefix=/opt/anaconda3/envs/curso
#   source=/opt/anaconda3/pkgs/r-rprojroot-2.0.3-r41hc72bb7e_0
#
#
# ===> LINKING PACKAGE: conda-forge::widgetsnbextension-3.6.1-pyha770c72_0 <===
#   prefix=/opt/anaconda3/envs/curso
#   source=/opt/anaconda3/pkgs/widgetsnbextension-3.6.1-pyha770c72_0
#
#
# ===> LINKING PACKAGE: conda-forge::ipywidgets-7.7.1-pyhd8ed1ab_0 <===
#   prefix=/opt/anaconda3/envs/curso
#   source=/opt/anaconda3/pkgs/ipywidgets-7.7.1-pyhd8ed1ab_0
#
#
# ===> LINKING PACKAGE: conda-forge::r-callr-3.7.1-r41hc72bb7e_0 <===
#   prefix=/opt/anaconda3/envs/curso
#   source=/opt/anaconda3/pkgs/r-callr-3.7.1-r41hc72bb7e_0
#
#
# ===> LINKING PACKAGE: conda-forge::r-desc-1.4.1-r41hc72bb7e_0 <===
#   prefix=/opt/anaconda3/envs/curso
#   source=/opt/anaconda3/pkgs/r-desc-1.4.1-r41hc72bb7e_0
#
#
# ===> LINKING PACKAGE: conda-forge::r-mgcv-1.8_40-r41h60b693f_0 <===
#   prefix=/opt/anaconda3/envs/curso
#   source=/opt/anaconda3/pkgs/r-mgcv-1.8_40-r41h60b693f_0
#
#
# ===> LINKING PACKAGE: conda-forge::r-scales-1.2.0-r41hc72bb7e_0 <===
#   prefix=/opt/anaconda3/envs/curso
#   source=/opt/anaconda3/pkgs/r-scales-1.2.0-r41hc72bb7e_0
#
#
# ===> LINKING PACKAGE: conda-forge::r-vctrs-0.4.1-r41hc4bb905_0 <===
#   prefix=/opt/anaconda3/envs/curso
#   source=/opt/anaconda3/pkgs/r-vctrs-0.4.1-r41hc4bb905_0
#
#
# ===> LINKING PACKAGE: conda-forge::jupyter-1.0.0-py37hf985489_7 <===
#   prefix=/opt/anaconda3/envs/curso
#   source=/opt/anaconda3/pkgs/jupyter-1.0.0-py37hf985489_7
#
#
# ===> LINKING PACKAGE: conda-forge::r-pillar-1.8.0-r41hc72bb7e_0 <===
#   prefix=/opt/anaconda3/envs/curso
#   source=/opt/anaconda3/pkgs/r-pillar-1.8.0-r41hc72bb7e_0
#
#
# ===> LINKING PACKAGE: conda-forge::r-pkgload-1.3.0-r41hc72bb7e_0 <===
#   prefix=/opt/anaconda3/envs/curso
#   source=/opt/anaconda3/pkgs/r-pkgload-1.3.0-r41hc72bb7e_0
#
#
# ===> LINKING PACKAGE: conda-forge::r-tibble-3.1.8-r41h67d6963_0 <===
#   prefix=/opt/anaconda3/envs/curso
#   source=/opt/anaconda3/pkgs/r-tibble-3.1.8-r41h67d6963_0
#
#
# ===> LINKING PACKAGE: conda-forge::r-rematch2-2.1.2-r41hc72bb7e_1 <===
#   prefix=/opt/anaconda3/envs/curso
#   source=/opt/anaconda3/pkgs/r-rematch2-2.1.2-r41hc72bb7e_1
#
#
# ===> LINKING PACKAGE: conda-forge::r-waldo-0.4.0-r41hc72bb7e_0 <===
#   prefix=/opt/anaconda3/envs/curso
#   source=/opt/anaconda3/pkgs/r-waldo-0.4.0-r41hc72bb7e_0
#
#
# ===> LINKING PACKAGE: conda-forge::r-testthat-3.1.4-r41h8619c4b_0 <===
#   prefix=/opt/anaconda3/envs/curso
#   source=/opt/anaconda3/pkgs/r-testthat-3.1.4-r41h8619c4b_0
#
#
# ===> LINKING PACKAGE: conda-forge::r-isoband-0.2.5-r41h9951f98_0 <===
#   prefix=/opt/anaconda3/envs/curso
#   source=/opt/anaconda3/pkgs/r-isoband-0.2.5-r41h9951f98_0
#
#
# ===> LINKING PACKAGE: conda-forge::r-ggplot2-3.3.6-r41hc72bb7e_0 <===
#   prefix=/opt/anaconda3/envs/curso
#   source=/opt/anaconda3/pkgs/r-ggplot2-3.3.6-r41hc72bb7e_0
#
#
# ===> LINKING PACKAGE: bioconda::busco-5.4.2-pyhdfd78af_0 <===
#   prefix=/opt/anaconda3/envs/curso
#   source=/opt/anaconda3/pkgs/busco-5.4.2-pyhdfd78af_0
#
#
# The default QUAST package does not include:
# * GRIDSS (needed for structural variants detection)
# * SILVA 16S rRNA database (needed for reference genome detection in metagenomic datasets)
# * BUSCO tools and databases (needed for searching BUSCO genes) -- works in Linux only!
#
# To be able to use those, please run
#     quast-download-gridss
#     quast-download-silva
#     quast-download-busco
#
# done

# %% [markdown]
# activar el paquete:

# %%
# !conda activate minimap2
